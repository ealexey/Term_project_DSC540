# %%
# %pwd
import pandas as pd
import numpy as np

# %%
#importing the merged_2011_2014.pkl data frame from milestone 2 
df1=pd.read_pickle("merged_2011_2014.pkl")
df1.head(10)
# Out:
#    temp_2011_2012  wind_speed_2011_2012     month_day  temp_2012_2013  \
# 0             285                  4.00  September 30             292
# 1             283                  7.00     October 1             291
# 2             286                  6.33     October 2             293
# 3             289                  4.33     October 3             293
# 4             291                  1.33     October 4             297
# 5             296                  1.00     October 5             296
# 6             297                  1.67     October 6             286
# 7             297                  3.00     October 7             282
# 8             298                  2.33     October 8             284
# 9             297                  1.00     October 9             287
#
#    wind_speed_2012_2013  temp_2013_2014  wind_speed_2013_2014
# 0                  4.33             294                  2.67
# 1                  3.67             297                  4.00
# 2                  1.67             300                  0.67
# 3                  6.00             299                  3.00
# 4                  7.33             300                  2.33
# 5                  4.00             300                  4.67
# 6                  4.33             298                  6.67
# 7                  4.00             287                  5.33
# 8                  2.33             291                  2.67
# 9                  5.00             294                  1.33

# %%
#importing the merged_2014_2017.pkl data frame from milestone 3
df2=pd.read_pickle("merged_2014_2017.pkl")
df2
# Out:
#      temp_min_2014_2015  temp_max_2014_2015  temp_2014_2015  \
# 0                282.55              286.15          284.77
# 1                281.15              286.11          283.89
# 2                281.15              285.35          283.05
# 3                291.15              294.15          292.88
# 4                278.15              280.15          279.14
# ..                  ...                 ...             ...
# 360              284.15              287.55          286.16
# 361              289.05              290.35          289.76
# 362              289.15              290.35          289.73
# 363              287.65              292.55          290.01
# 364              292.75              293.75          293.22
#
#      wind_speed_2014_2015     month_day  temp_min_2015_2016  \
# 0                    1.50  September 30              287.15
# 1                    1.65     October 1              282.95
# 2                    1.50     October 2              281.25
# 3                    5.70     October 3              279.65
# 4                    6.20     October 4              283.65
# ..                    ...           ...                 ...
# 360                  2.60  September 25              283.71
# 361                  3.60  September 26              288.15
# 362                  3.60  September 27              279.26
# 363                  2.03  September 28              283.15
# 364                  1.50  September 29              285.15
#
#      temp_max_2015_2016  temp_2015_2016  wind_speed_2015_2016  \
# 0               289.250          288.47                   5.1
# 1               285.059          284.03                   4.6
# 2               283.428          282.28                   6.2
# 3               281.450          280.44                   6.2
# 4               284.388          284.07                   3.1
# ..                  ...             ...                   ...
# 360             287.592          285.26                   2.1
# 361             292.150          290.06                   2.6
# 362             283.150          281.56                   2.1
# 363             287.550          285.64                   1.5
# 364             287.550          286.49                   1.5
#
#      temp_min_2016_2017  temp_max_2016_2017  temp_2016_2017  \
# 0                288.75             290.150          289.44
# 1                282.15             285.804          284.23
# 2                285.15             288.025          286.75
# 3                281.75             285.150          284.00
# 4                281.45             286.150          284.28
# ..                  ...                 ...             ...
# 360              287.55             291.790          290.06
# 361              287.05             292.092          289.25
# 362              288.15             292.315          290.13
# 363              284.15             288.882          286.32
# 364              278.15             282.680          280.02
#
#      wind_speed_2016_2017
# 0                    3.60
# 1                    2.10
# 2                    2.60
# 3                    1.10
# 4                    1.50
# ..                    ...
# 360                  1.51
# 361                  0.87
# 362                  1.84
# 363                  4.60
# 364                  1.03
#
# [365 rows x 13 columns]

# %%
##importing the merged_2017_2020.pkl data frame from milestone 4
df3=pd.read_pickle("merged_2017_2020.pkl")
df3
# Out:
#      temp_2017_2018  max_temp_2017_2018  min_temp_2017_2018  \
# 0            286.17              292.33              280.83
# 1            286.11              293.67              279.17
# 2            289.06              297.33              279.67
# 3            292.22              300.83              282.33
# 4            294.06              300.83              286.83
# ..              ...                 ...                 ...
# 360          294.78              296.83              293.06
# 361          292.33              295.17              286.33
# 362          286.56              290.17              284.17
# 363          288.11              295.83              280.83
# 364          287.44              292.33              282.33
#
#      wind_speed_2017_2018     month_day  temp_2018_2019  max_temp_2018_2019  \
# 0                    5.00  September 30          291.39              298.67
# 1                    4.27     October 1          294.17              301.83
# 2                    2.30     October 2          295.50              299.67
# 3                    4.27     October 3          296.22              301.83
# 4                    4.63     October 4          294.22              298.06
# ..                    ...           ...             ...                 ...
# 360                  4.27  September 25          293.17              300.17
# 361                  5.37  September 26          293.06              298.06
# 362                  3.43  September 27          292.89              303.06
# 363                  3.43  September 28          296.83              303.67
# 364                  3.07  September 29          294.11              298.06
#
#      min_temp_2018_2019  wind_speed_2018_2019  temp_2019_2020  \
# 0                284.67                  2.70          297.89
# 1                286.33                  3.80          298.89
# 2                293.06                  4.63          298.78
# 3                290.83                  5.00          297.06
# 4                285.83                  5.37          287.39
# ..                  ...                   ...             ...
# 360              284.67                  5.00          292.61
# 361              286.33                  5.00          294.39
# 362              283.06                  5.73          293.28
# 363              291.33                  5.37          290.72
# 364              290.83                  3.43          285.89
#
#      max_temp_2019_2020  min_temp_2019_2020  wind_speed_2019_2020
# 0                305.17              291.33                  2.70
# 1                305.83              292.33                  5.73
# 2                305.83              292.33                  5.37
# 3                305.17              289.67                  7.30
# 4                291.83              283.06                  5.00
# ..                  ...                 ...                   ...
# 360              299.67              284.67                  3.43
# 361              300.17              288.06                  5.00
# 362              298.06              289.17                  5.73
# 363              297.33              285.17                  5.37
# 364              289.67              280.83                  3.07
#
# [365 rows x 13 columns]

# %%
#merging all 3 dataframes from milestone 2, 3, and 4
merged=pd.merge(df1, df2, on="month_day", how="outer" )
merged=pd.merge(merged, df3, on="month_day", how="outer")
merged
# Out:
#      temp_2011_2012  wind_speed_2011_2012     month_day  temp_2012_2013  \
# 0               285                  4.00  September 30             292
# 1               283                  7.00     October 1             291
# 2               286                  6.33     October 2             293
# 3               289                  4.33     October 3             293
# 4               291                  1.33     October 4             297
# ..              ...                   ...           ...             ...
# 360             291                  6.33  September 25             294
# 361             294                  6.00  September 26             297
# 362             292                  2.67  September 27             297
# 363             291                  2.67  September 28             298
# 364             293                  1.67  September 29             296
#
#      wind_speed_2012_2013  temp_2013_2014  wind_speed_2013_2014  \
# 0                    4.33             294                  2.67
# 1                    3.67             297                  4.00
# 2                    1.67             300                  0.67
# 3                    6.00             299                  3.00
# 4                    7.33             300                  2.33
# ..                    ...             ...                   ...
# 360                  1.67             298                  2.67
# 361                  3.00             299                  1.00
# 362                  1.00             299                  2.67
# 363                  2.00             301                  1.00
# 364                  3.67             301                  0.67
#
#      temp_min_2014_2015  temp_max_2014_2015  temp_2014_2015  ...  \
# 0                282.55              286.15          284.77  ...
# 1                281.15              286.11          283.89  ...
# 2                281.15              285.35          283.05  ...
# 3                291.15              294.15          292.88  ...
# 4                278.15              280.15          279.14  ...
# ..                  ...                 ...             ...  ...
# 360              284.15              287.55          286.16  ...
# 361              289.05              290.35          289.76  ...
# 362              289.15              290.35          289.73  ...
# 363              287.65              292.55          290.01  ...
# 364              292.75              293.75          293.22  ...
#
#      min_temp_2017_2018  wind_speed_2017_2018  temp_2018_2019  \
# 0                280.83                  5.00          291.39
# 1                279.17                  4.27          294.17
# 2                279.67                  2.30          295.50
# 3                282.33                  4.27          296.22
# 4                286.83                  4.63          294.22
# ..                  ...                   ...             ...
# 360              293.06                  4.27          293.17
# 361              286.33                  5.37          293.06
# 362              284.17                  3.43          292.89
# 363              280.83                  3.43          296.83
# 364              282.33                  3.07          294.11
#
#      max_temp_2018_2019  min_temp_2018_2019  wind_speed_2018_2019  \
# 0                298.67              284.67                  2.70
# 1                301.83              286.33                  3.80
# 2                299.67              293.06                  4.63
# 3                301.83              290.83                  5.00
# 4                298.06              285.83                  5.37
# ..                  ...                 ...                   ...
# 360              300.17              284.67                  5.00
# 361              298.06              286.33                  5.00
# 362              303.06              283.06                  5.73
# 363              303.67              291.33                  5.37
# 364              298.06              290.83                  3.43
#
#      temp_2019_2020  max_temp_2019_2020  min_temp_2019_2020  \
# 0            297.89              305.17              291.33
# 1            298.89              305.83              292.33
# 2            298.78              305.83              292.33
# 3            297.06              305.17              289.67
# 4            287.39              291.83              283.06
# ..              ...                 ...                 ...
# 360          292.61              299.67              284.67
# 361          294.39              300.17              288.06
# 362          293.28              298.06              289.17
# 363          290.72              297.33              285.17
# 364          285.89              289.67              280.83
#
#      wind_speed_2019_2020
# 0                    2.70
# 1                    5.73
# 2                    5.37
# 3                    7.30
# 4                    5.00
# ..                    ...
# 360                  3.43
# 361                  5.00
# 362                  5.73
# 363                  5.37
# 364                  3.07
#
# [365 rows x 31 columns]

# %%
"""plitting the column month_day into two columns (the first way) the month column will be used for grouping using
the groupby() method"""
import re
pattern=re.compile(r"[a-zA-Z]+") #pattern to exctract month
month=[pattern.search(i).group() for i in merged["month_day"]]
pattern1=re.compile(r"\d+") #pattern to exctract day
day=[pattern1.search(i).group() for i in merged["month_day"]]
merged["month"]=month
merged["day"]=day
merged.drop(columns=["month_day"], inplace=True)
merged
# Out:
#      temp_2011_2012  wind_speed_2011_2012  temp_2012_2013  \
# 0               285                  4.00             292
# 1               283                  7.00             291
# 2               286                  6.33             293
# 3               289                  4.33             293
# 4               291                  1.33             297
# ..              ...                   ...             ...
# 360             291                  6.33             294
# 361             294                  6.00             297
# 362             292                  2.67             297
# 363             291                  2.67             298
# 364             293                  1.67             296
#
#      wind_speed_2012_2013  temp_2013_2014  wind_speed_2013_2014  \
# 0                    4.33             294                  2.67
# 1                    3.67             297                  4.00
# 2                    1.67             300                  0.67
# 3                    6.00             299                  3.00
# 4                    7.33             300                  2.33
# ..                    ...             ...                   ...
# 360                  1.67             298                  2.67
# 361                  3.00             299                  1.00
# 362                  1.00             299                  2.67
# 363                  2.00             301                  1.00
# 364                  3.67             301                  0.67
#
#      temp_min_2014_2015  temp_max_2014_2015  temp_2014_2015  \
# 0                282.55              286.15          284.77
# 1                281.15              286.11          283.89
# 2                281.15              285.35          283.05
# 3                291.15              294.15          292.88
# 4                278.15              280.15          279.14
# ..                  ...                 ...             ...
# 360              284.15              287.55          286.16
# 361              289.05              290.35          289.76
# 362              289.15              290.35          289.73
# 363              287.65              292.55          290.01
# 364              292.75              293.75          293.22
#
#      wind_speed_2014_2015  ...  temp_2018_2019  max_temp_2018_2019  \
# 0                    1.50  ...          291.39              298.67
# 1                    1.65  ...          294.17              301.83
# 2                    1.50  ...          295.50              299.67
# 3                    5.70  ...          296.22              301.83
# 4                    6.20  ...          294.22              298.06
# ..                    ...  ...             ...                 ...
# 360                  2.60  ...          293.17              300.17
# 361                  3.60  ...          293.06              298.06
# 362                  3.60  ...          292.89              303.06
# 363                  2.03  ...          296.83              303.67
# 364                  1.50  ...          294.11              298.06
#
#      min_temp_2018_2019  wind_speed_2018_2019  temp_2019_2020  \
# 0                284.67                  2.70          297.89
# 1                286.33                  3.80          298.89
# 2                293.06                  4.63          298.78
# 3                290.83                  5.00          297.06
# 4                285.83                  5.37          287.39
# ..                  ...                   ...             ...
# 360              284.67                  5.00          292.61
# 361              286.33                  5.00          294.39
# 362              283.06                  5.73          293.28
# 363              291.33                  5.37          290.72
# 364              290.83                  3.43          285.89
#
#      max_temp_2019_2020  min_temp_2019_2020  wind_speed_2019_2020      month  \
# 0                305.17              291.33                  2.70  September
# 1                305.83              292.33                  5.73    October
# 2                305.83              292.33                  5.37    October
# 3                305.17              289.67                  7.30    October
# 4                291.83              283.06                  5.00    October
# ..                  ...                 ...                   ...        ...
# 360              299.67              284.67                  3.43  September
# 361              300.17              288.06                  5.00  September
# 362              298.06              289.17                  5.73  September
# 363              297.33              285.17                  5.37  September
# 364              289.67              280.83                  3.07  September
#
#      day
# 0     30
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 360   25
# 361   26
# 362   27
# 363   28
# 364   29
#
# [365 rows x 32 columns]

# %%
import sqlite3 as sql
conn = sql.connect('merged1.db')
merged.to_sql('merged1', conn)

# %%
#the merged dataset contains some numbers with different amount of decimal numbers, for example 7.999999998 and 3.45 
#in spite of rounding data in all datasets. The merded dataset will be cleaned again
a=(len(merged.columns)-3)
for col in merged.columns[:a]:
    merged[col]=([round(i,2) for i in merged[col]])
merged
# Out:
#      temp_2011_2012  wind_speed_2011_2012  temp_2012_2013  \
# 0               285                  4.00             292
# 1               283                  7.00             291
# 2               286                  6.33             293
# 3               289                  4.33             293
# 4               291                  1.33             297
# ..              ...                   ...             ...
# 360             291                  6.33             294
# 361             294                  6.00             297
# 362             292                  2.67             297
# 363             291                  2.67             298
# 364             293                  1.67             296
#
#      wind_speed_2012_2013  temp_2013_2014  wind_speed_2013_2014  \
# 0                    4.33             294                  2.67
# 1                    3.67             297                  4.00
# 2                    1.67             300                  0.67
# 3                    6.00             299                  3.00
# 4                    7.33             300                  2.33
# ..                    ...             ...                   ...
# 360                  1.67             298                  2.67
# 361                  3.00             299                  1.00
# 362                  1.00             299                  2.67
# 363                  2.00             301                  1.00
# 364                  3.67             301                  0.67
#
#      temp_min_2014_2015  temp_max_2014_2015  temp_2014_2015  \
# 0                282.55              286.15          284.77
# 1                281.15              286.11          283.89
# 2                281.15              285.35          283.05
# 3                291.15              294.15          292.88
# 4                278.15              280.15          279.14
# ..                  ...                 ...             ...
# 360              284.15              287.55          286.16
# 361              289.05              290.35          289.76
# 362              289.15              290.35          289.73
# 363              287.65              292.55          290.01
# 364              292.75              293.75          293.22
#
#      wind_speed_2014_2015  ...  temp_2018_2019  max_temp_2018_2019  \
# 0                    1.50  ...          291.39              298.67
# 1                    1.65  ...          294.17              301.83
# 2                    1.50  ...          295.50              299.67
# 3                    5.70  ...          296.22              301.83
# 4                    6.20  ...          294.22              298.06
# ..                    ...  ...             ...                 ...
# 360                  2.60  ...          293.17              300.17
# 361                  3.60  ...          293.06              298.06
# 362                  3.60  ...          292.89              303.06
# 363                  2.03  ...          296.83              303.67
# 364                  1.50  ...          294.11              298.06
#
#      min_temp_2018_2019  wind_speed_2018_2019  temp_2019_2020  \
# 0                284.67                  2.70          297.89
# 1                286.33                  3.80          298.89
# 2                293.06                  4.63          298.78
# 3                290.83                  5.00          297.06
# 4                285.83                  5.37          287.39
# ..                  ...                   ...             ...
# 360              284.67                  5.00          292.61
# 361              286.33                  5.00          294.39
# 362              283.06                  5.73          293.28
# 363              291.33                  5.37          290.72
# 364              290.83                  3.43          285.89
#
#      max_temp_2019_2020  min_temp_2019_2020  wind_speed_2019_2020      month  \
# 0                305.17              291.33                  2.70  September
# 1                305.83              292.33                  5.73    October
# 2                305.83              292.33                  5.37    October
# 3                305.17              289.67                  7.30    October
# 4                291.83              283.06                  5.00    October
# ..                  ...                 ...                   ...        ...
# 360              299.67              284.67                  3.43  September
# 361              300.17              288.06                  5.00  September
# 362              298.06              289.17                  5.73  September
# 363              297.33              285.17                  5.37  September
# 364              289.67              280.83                  3.07  September
#
#      day
# 0     30
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 360   25
# 361   26
# 362   27
# 363   28
# 364   29
#
# [365 rows x 32 columns]

# %%
#creating a new column that correspond to the month number to sort data frame rows from January (1) to December (12)
def month_to_number(month):
    if month=="January":
        return 1
    elif month=="February":
        return 2
    elif month=="March":
        return 3
    elif month=="April":
        return 4
    elif month=="May":
        return 5
    elif month=="June":
        return 6
    elif month=="July":
        return 7
    elif month=="August":
        return 8
    elif month=="September":
        return 9
    elif month=="October":
        return 10
    elif month=="November":
        return 11
    elif month=="December":
        return 12
merged["month_number"]=merged["month"]
merged["month_number"]=merged["month_number"].apply(month_to_number)
merged.drop(columns=["day"], inplace=True)
merged
# Out:
#      temp_2011_2012  wind_speed_2011_2012  temp_2012_2013  \
# 0               285                  4.00             292
# 1               283                  7.00             291
# 2               286                  6.33             293
# 3               289                  4.33             293
# 4               291                  1.33             297
# ..              ...                   ...             ...
# 360             291                  6.33             294
# 361             294                  6.00             297
# 362             292                  2.67             297
# 363             291                  2.67             298
# 364             293                  1.67             296
#
#      wind_speed_2012_2013  temp_2013_2014  wind_speed_2013_2014  \
# 0                    4.33             294                  2.67
# 1                    3.67             297                  4.00
# 2                    1.67             300                  0.67
# 3                    6.00             299                  3.00
# 4                    7.33             300                  2.33
# ..                    ...             ...                   ...
# 360                  1.67             298                  2.67
# 361                  3.00             299                  1.00
# 362                  1.00             299                  2.67
# 363                  2.00             301                  1.00
# 364                  3.67             301                  0.67
#
#      temp_min_2014_2015  temp_max_2014_2015  temp_2014_2015  \
# 0                282.55              286.15          284.77
# 1                281.15              286.11          283.89
# 2                281.15              285.35          283.05
# 3                291.15              294.15          292.88
# 4                278.15              280.15          279.14
# ..                  ...                 ...             ...
# 360              284.15              287.55          286.16
# 361              289.05              290.35          289.76
# 362              289.15              290.35          289.73
# 363              287.65              292.55          290.01
# 364              292.75              293.75          293.22
#
#      wind_speed_2014_2015  ...  temp_2018_2019  max_temp_2018_2019  \
# 0                    1.50  ...          291.39              298.67
# 1                    1.65  ...          294.17              301.83
# 2                    1.50  ...          295.50              299.67
# 3                    5.70  ...          296.22              301.83
# 4                    6.20  ...          294.22              298.06
# ..                    ...  ...             ...                 ...
# 360                  2.60  ...          293.17              300.17
# 361                  3.60  ...          293.06              298.06
# 362                  3.60  ...          292.89              303.06
# 363                  2.03  ...          296.83              303.67
# 364                  1.50  ...          294.11              298.06
#
#      min_temp_2018_2019  wind_speed_2018_2019  temp_2019_2020  \
# 0                284.67                  2.70          297.89
# 1                286.33                  3.80          298.89
# 2                293.06                  4.63          298.78
# 3                290.83                  5.00          297.06
# 4                285.83                  5.37          287.39
# ..                  ...                   ...             ...
# 360              284.67                  5.00          292.61
# 361              286.33                  5.00          294.39
# 362              283.06                  5.73          293.28
# 363              291.33                  5.37          290.72
# 364              290.83                  3.43          285.89
#
#      max_temp_2019_2020  min_temp_2019_2020  wind_speed_2019_2020      month  \
# 0                305.17              291.33                  2.70  September
# 1                305.83              292.33                  5.73    October
# 2                305.83              292.33                  5.37    October
# 3                305.17              289.67                  7.30    October
# 4                291.83              283.06                  5.00    October
# ..                  ...                 ...                   ...        ...
# 360              299.67              284.67                  3.43  September
# 361              300.17              288.06                  5.00  September
# 362              298.06              289.17                  5.73  September
# 363              297.33              285.17                  5.37  September
# 364              289.67              280.83                  3.07  September
#
#      month_number
# 0               9
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 360             9
# 361             9
# 362             9
# 363             9
# 364             9
#
# [365 rows x 32 columns]

# %%
#histograms for numerical variables in the merged dataframe
import matplotlib.pyplot as plt
for col in merged.columns[:a]:
    plt.title("Histogram of "+col,fontsize=15)
    plt.hist(merged[col].dropna(), bins=20)
    plt.show()

# %%
#boxplots for numerical variables in the merged dataframe
for col in merged.columns[:a]:
    merged.boxplot(col)
    plt.show()

# %%
"""generation of the dataframe by_month["temp_2011_2012"]. This dataframe contains month's names as index
and has two columns. The first column indicates the mean temperature for corresponding month and the second
column indicates the standard deviation for the corresponding month"""
merged.sort_values(["month_number"], inplace=True)
by_month=merged.groupby("month", sort=False).agg([np.mean, np.std])
by_month["temp_2011_2012"]
# Out:
#                  mean       std
# month
# January    275.290323  5.716605
# February   277.321429  4.714466
# March      288.483871  7.650146
# April      288.466667  5.110728
# May        297.741935  4.163074
# June       299.433333  4.336559
# July       301.870968  3.127746
# August     300.193548  3.350814
# September  294.833333  4.243318
# October    289.032258  5.689076
# November   284.666667  4.293807
# December   278.645161  4.159715

# %%
"""bar plot with errorbars. Each bar with errorbar corresponds to the mean temperature for the corresponding month
The period encompasses dates from September 30, """ 
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
month = by_month["temp_2011_2012"]
ax.set_title("The mean monthly temperature from 09/30/2011 to 09/29/2012")
ax.bar(x=month.index, height=month[month.columns[0]]-273, yerr=month[month.columns[1]], capsize=6)
plt.show()

# %%
"""grouped bar chart with errorbars. This bar chart shows mean temperature for each months for two periods
1. 09/30/2011 to 09/29/2012
2. 09/30/2018 to 09/29/2019
"""
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
month = by_month["temp_2011_2012"]
month1=by_month["temp_2018_2019"]
width=0.25
labels=month.index
x=np.arange(len(labels))
labels=month.index
ax.set_ylabel('Temperature C')
ax.set_title('Temperature of 2011-2012 and 2018-2019')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.bar(x-width/2, month[month.columns[0]]-273,  width, yerr=month[month.columns[1]], capsize=6, label="2011-2012")
ax.bar(x+width/2, month1[month1.columns[0]]-273, width, yerr=month1[month1.columns[1]],  capsize=6, label="2018-2019")
ax.legend()
plt.show()

# %%
"""Scatter plot wind speed vs temperature for the period from 09/30/2019 to 09/29/2020.
This graph shows that there is no correlation between wind speed and temperature"""
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.scatter(merged["temp_2019_2020"], merged["wind_speed_2019_2020"])

ax.set_xlabel('Temperature')
ax.set_title('Temperature vs wind speed 2019-2020')
ax.set_ylabel("Wind speed")
# Out:
# Text(0, 0.5, 'Wind speed')
